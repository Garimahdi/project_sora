# %%
import pandas as pd
import numpy as np

# %%
test = pd.read_excel(
    r"D:\Astragraphia\BO1\Revenue Analysis_jan-jul\2023 Datasets\MIF Des 2023.xlsx",
    sheet_name = 'EDS'
)
ct = list(test.columns)
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 868 entries, 0 to 867
# Data columns (total 63 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unit                868 non-null    int64
#  1   Dv                  868 non-null    int64
#  2   YTD                 868 non-null    object
#  3   Cabang              868 non-null    object
#  4   Divisi              868 non-null    object
#  5   Zona                868 non-null    object
#  6   Matl Group          868 non-null    object
#  7   Model number        868 non-null    object
#  8   SaTy                868 non-null    object
#  9   User Status         868 non-null    object
#  10  ShipTo Cnt          868 non-null    int64
#  11  ShipTo Eq.          863 non-null    float64
#  12  Equipmnt            868 non-null    int64
#  13  S/ N                868 non-null    int64
#  14  MBU                 868 non-null    object
# ...

# %%
a = test[ct[62]].unique()

# %%
th_df = test.loc[test[ct[62]] == a[13]]
th_df[ct[27]]
#th_df[ct[62]] th_df[ct[62]].apply(lambda x: x.split())
x = th_df.loc[th_df[ct[27]].apply(lambda x: not x.startswith('J'))]
x
# Out:
#      Unit  Dv     YTD    Cabang Divisi         Zona Matl Group Model number  \
# 79      1  21  Des 23  Jakarta1    BO2  Jabodetabek       OC10   DC6C3370ST
# 96      1  21  Des 23  Jakarta1    BO2  Jabodetabek       OC16   AP5C3375ST
# 195     1  21  Des 23  Jakarta1    BO2  Jabodetabek       OC18    AC2560CPS
# 196     1  21  Des 23  Jakarta1    BO2  Jabodetabek       OC18    AC2560CPS
# 218     1  21  Des 23  Jakarta1    BO2  Jabodetabek       OB15    DCV2060CP
# 227     1  21  Des 23  Jakarta1    BO2  Jabodetabek       OB15    DCV2060CP
# 228     1  21  Des 23  Jakarta1    BO2  Jabodetabek       OB15    DCV2060CP
# 232     1  21  Des 23  Jakarta1    BO2  Jabodetabek       OB21     A2560CPS
# 409     1  21  Des 23  Jakarta1    BO2  Jabodetabek       OC12   DC5C2265ST
# 457     1  21  Des 23  Jakarta1    BO2  Jabodetabek       OC18   AP5C3320ST
# 480     1  21  Des 23  Jakarta1    BO2  Jabodetabek       OC18  AP5C2276CPS
# ...

# %%
x1 = x.apply(lambda y:y.lower().split('jl'))
x2 = x1.apply(lambda x: x[0])
#print(x2)
x3 = x2.apply(lambda z: z.split('lt'))
#print(x3.apply(lambda x:x[0]))
x4 = x3.apply(lambda x:x[0])
x5 = x4.apply(lambda x:x.split(','))
xx1 = x5.apply(lambda x: x[0])
